# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from statsmodels.formula.api import ols
import statsmodels.stats.api as sms
import statsmodels.api as sm
import math
import statistics

# %matplotlib notebook

# %%
deep = pd.read_excel('data.xlsx').sort_values(by='Squad').reset_index().drop(columns='index')
deep = deep.rename(columns={'xG+xA': 'xGxA'})
deep.head()
# Out:
#             Player  Nation Pos   Squad  Gls.1  Ast1    GA  xGxA    KP  \
# 0      Lucas Pérez  es ESP  FW  Alavés   0.40  0.18  0.58  0.57  2.17
# 1  Tomás Pina Isla  es ESP  MF  Alavés   0.07  0.00  0.07  0.09  0.27
# 2      Aleix Vidal  es ESP  MF  Alavés   0.08  0.17  0.25  0.26  1.62
# 3  Víctor Camarasa  es ESP  MF  Alavés   0.00  0.07  0.07  0.13  0.97
# 4           Wakaso  gh GHA  MF  Alavés   0.00  0.00  0.00  0.03  0.14
#
#     Effrate    cc
# 0  0.430685  2.35
# 1  0.100868  0.27
# 2  0.301027  1.79
# 3  0.137094  1.04
# 4  0.033114  0.14

# %%
deep.plot(kind='scatter', x='Effrate', y='GA');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
deep.plot(kind='scatter', x='xGxA', y='GA');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
reg = ols('GA ~ Effrate', data = deep).fit()
print(reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     GA   R-squared:                       0.472
# Model:                            OLS   Adj. R-squared:                  0.469
# Method:                 Least Squares   F-statistic:                     160.0
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):           1.30e-26
# Time:                        20:17:59   Log-Likelihood:                 80.110
# No. Observations:                 181   AIC:                            -156.2
# Df Residuals:                     179   BIC:                            -149.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1379      0.016      8.561      0.000       0.106       0.170
# Effrate        0.5596      0.044     12.649      0.000       0.472       0.647
# ==============================================================================
# Omnibus:                       18.817   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.821
# Skew:                           0.745   Prob(JB):                     1.83e-05
# Kurtosis:                       3.821   Cond. No.                         4.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
labels = ['LM Statistic', 'LM-Test p-value']
test = sms.het_breuschpagan(reg.resid,reg.model.exog)
for stat,value in zip(labels,test[:2]):
    print('{}: {:.3f}'.format(stat,value))
# Out:
# LM Statistic: 7.475
# LM-Test p-value: 0.006

# %% [markdown]
# The model is heteroskedastic, so we will parse it fixing errors as robust

# %%
reg = ols('GA ~ Effrate', data = deep).fit(cov_type='HC3')
print(reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     GA   R-squared:                       0.472
# Model:                            OLS   Adj. R-squared:                  0.469
# Method:                 Least Squares   F-statistic:                     61.24
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):           4.24e-13
# Time:                        20:17:59   Log-Likelihood:                 80.110
# No. Observations:                 181   AIC:                            -156.2
# Df Residuals:                     179   BIC:                            -149.8
# Df Model:                           1
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1379      0.019      7.451      0.000       0.102       0.174
# Effrate        0.5596      0.072      7.826      0.000       0.419       0.700
# ==============================================================================
# Omnibus:                       18.817   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.821
# Skew:                           0.745   Prob(JB):                     1.83e-05
# Kurtosis:                       3.821   Cond. No.                         4.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
plt.style.use('ggplot')
a = sm.qqplot(reg.resid,fit=True)
plt.title('Simple Q-Q Plot')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.rc('figure',figsize=(7,6))
plt.style.use('ggplot')

probplot = sm.ProbPlot(reg.get_influence().resid_studentized_internal,fit=True) #qqplot done based on studentized residuals
fig = probplot.qqplot(line='45',marker='o',color='black')
plt.title('Normal Q-Q',fontsize=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
# C:\Users\aleex\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
sentence = '{} = {}'
b,a,r_value,p_value,std_err = stats.linregress(x=deep.Effrate,y=deep.GA)
rsq=r_value**2
print(sentence.format('rsq',rsq.round(2)))
print(sentence.format('a',a.round(2)))
print(sentence.format('b',b.round(2)))
print(sentence.format('std_err',std_err.round(2)))
print(sentence.format('pvalue',p_value.round(5)))
# Out:
# rsq = 0.47
# a = 0.14
# b = 0.56
# std_err = 0.04
# pvalue = 0.0

# %% [markdown]
# **According to this model, a 47% of each goal or assist can be explained by the model, and a goal or assist in 90 minutes of playing comes alongside an increase of 0.56 of the EFFRATE of the same player. In other words, every 0.56 units of offensive profit would lead into a goal or assist (real production), according to the model**

# %%
e = reg.resid
deep['e'] = e
deep = deep.sort_values(by='e',ascending=False)
deep.tail(10)
# Out:
#               Player  Nation    Pos        Squad  Gls.1  Ast1    GA  xGxA  \
# 43    Sergio Canales  es ESP  MF,FW        Betis   0.17  0.17  0.34  0.36
# 132             Isco  es ESP  FW,MF  Real Madrid   0.08  0.15  0.23  0.28
# 115    Salva Sevilla  es ESP     MF     Mallorca   0.18  0.11  0.28  0.25
# 57    Sergio Álvarez  es ESP  MF,DF        Eibar   0.00  0.00  0.00  0.04
# 97      Aitor Ruibal  es ESP  DF,FW      Leganés   0.00  0.00  0.00  0.12
# 6         Luis Rioja  es ESP     MF       Alavés   0.00  0.00  0.00  0.15
# 127  Vinicius Júnior  br BRA  FW,MF  Real Madrid   0.20  0.07  0.26  0.45
# 171         Antoñito  es ESP  DF,MF   Valladolid   0.00  0.00  0.00  0.15
# 126       Toni Kroos  de GER     MF  Real Madrid   0.14  0.17  0.31  0.23
# 41           Joaquín  es ESP  MF,FW        Betis   0.35  0.13  0.48  0.48
#
#        KP   Effrate    cc         e
# 43   2.17  0.689355  2.34 -0.183686
# 132  1.76  0.512108  1.91 -0.194504
# 115  1.89  0.602005  2.00 -0.194808
# 57   0.55  0.103112  0.55 -0.195642
# 97   0.81  0.106287  0.81 -0.197419
# 6    0.88  0.121002  0.88 -0.205653
# 127  1.45  0.626428  1.52 -0.228474
# 171  0.88  0.194776  0.88 -0.246935
# 126  2.14  0.899748  2.31 -0.331416
# 41   2.66  1.360021  2.79 -0.418971

# %%
plt.figure()
sns.regplot(x='Effrate', y='GA', data = deep,ci=False,line_kws = {'color':'cyan'},color='lightsalmon')
plt.xlabel('Efficiency Rate')
plt.ylabel('Goals+Assists/90 min')
plt.title('Simple Regression [{} - {}]'.format('Effrate','Goals+Assists'))
plt.annotate('y = {}x + {}'.format(b.round(2),a.round(2)),(0.25,1.45))
plt.annotate('rsq = {}'.format(rsq.round(2)),(0.25,1.35))
sns.set(rc={'figure.figsize':(7,6)},style='white')
sns.despine()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
JBpv = sm.stats.stattools.jarque_bera(reg.resid)[1]
JBpv.round(2)
# Out:
# 0.0

# %%
plt.figure()
sns.residplot(reg.fittedvalues, 'GA',data=deep, lowess=True,
             scatter_kws={'facecolors':'none', 'edgecolors':'black'}, 
                          line_kws={'color': 'blue', 'lw': 1, 'alpha': 0.8})
plt.title('Residuals vs Fitted', fontsize=20)
plt.xlabel('Fitted Values', fontsize=15)
plt.ylabel('Residuals', fontsize=15)
# Out:
# <img src="data:image/png;base64,..." width="700">
# C:\Users\aleex\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Residuals')

# %%
mult = ols('GA ~ Effrate + KP + cc', data = deep).fit(cov_type='HC3')
print(mult.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     GA   R-squared:                       0.598
# Model:                            OLS   Adj. R-squared:                  0.591
# Method:                 Least Squares   F-statistic:                     37.75
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):           6.58e-19
# Time:                        20:17:59   Log-Likelihood:                 104.71
# No. Observations:                 181   AIC:                            -201.4
# Df Residuals:                     177   BIC:                            -188.6
# Df Model:                           3
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1236      0.020      6.227      0.000       0.085       0.163
# Effrate        0.4060      0.149      2.732      0.006       0.115       0.697
# KP            -1.1642      0.202     -5.775      0.000      -1.559      -0.769
# cc             1.1007      0.170      6.464      0.000       0.767       1.434
# ==============================================================================
# Omnibus:                       29.306   Durbin-Watson:                   0.378
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.801
# Skew:                           1.061   Prob(JB):                     6.19e-09
# Kurtosis:                       3.711   Cond. No.                         41.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
statistics.variance(mult.resid)
# Out:
# 0.018512424648424907

# %% [markdown]
# **According to this regression model, the relationship between key passes and goals/assists of a player is negative, probably because the correlation between this factor and the others (KP is part of the formula of CC and Effrate), so multicolinearity is clearly present in the model. Here, acc to JB, residuals are not normally distributed**

# %%
plt.rc('figure',figsize=(7,6))
plt.style.use('ggplot')

probplot = sm.ProbPlot(mult.get_influence().resid_studentized_internal,fit=True) #qqplot done based on studentized residuals
fig = probplot.qqplot(line='45',marker='o',color='black')
plt.title('Normal Q-Q',fontsize=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
# C:\Users\aleex\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.2980392156862745, 0.4470588235294118, 0.6901960784313725, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
plt.style.use('ggplot')
a = sm.qqplot(mult.resid,fit=True)
plt.title('Simple Q-Q Plot')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
xgxa = ols('GA ~ xGxA', data = deep).fit(cov_type='HC3')
print(xgxa.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     GA   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     402.9
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):           1.07e-47
# Time:                        20:17:59   Log-Likelihood:                 178.48
# No. Observations:                 181   AIC:                            -353.0
# Df Residuals:                     179   BIC:                            -346.6
# Df Model:                           1
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0183      0.013     -1.370      0.171      -0.045       0.008
# xGxA           1.1269      0.056     20.072      0.000       1.017       1.237
# ==============================================================================
# Omnibus:                        1.379   Durbin-Watson:                   1.697
# Prob(Omnibus):                  0.502   Jarque-Bera (JB):                1.037
# Skew:                          -0.036   Prob(JB):                        0.595
# Kurtosis:                       3.364   Cond. No.                         6.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %% [markdown]
# **As we could have predicted, xG+xA is a good estimator of real Goals+Assists, as this model can explain a 82% of the whole goals/assists of the analysis. To registering every unit of real production, there is an increase of expected production in 1.13 units**

# %%
statistics.variance(xgxa.resid)
# Out:
# 0.008193076423932088

# %%
deep['exgxa'] = xgxa.resid
deep = deep.sort_values(by='exgxa',ascending=False)
print(deep.head(10))
print('\n')
print(deep.tail(10))
# Out:
#                      Player  Nation    Pos          Squad  Gls.1  Ast1    GA  \
# 34              Arthur Melo  br BRA     MF      Barcelona   0.23  0.23  0.46
# 78          Ángel Rodríguez  es ESP     FW         Getafe   0.64  0.19  0.83
# 33             Lionel Messi  ar ARG  FW,MF      Barcelona   0.78  0.62  1.41
# 30              Luis Suárez  uy URU     FW      Barcelona   0.72  0.36  1.08
# 135             Luka Modrić  hr CRO     MF    Real Madrid   0.14  0.32  0.45
# 27                Ansu Fati  es ESP  FW,DF      Barcelona   0.61  0.09  0.70
# 147        Munir El Haddadi  es ESP     FW        Sevilla   0.36  0.14  0.50
# 72              David López  es ESP  DF,MF       Espanyol   0.15  0.07  0.22
# 16            Iñigo Córdoba  es ESP     FW  Athletic Club   0.06  0.25  0.31
# 91   Óscar Rodríguez Arnaiz  es ESP  MF,FW        Leganés   0.42  0.09  0.52
#
#      xGxA    KP   Effrate    cc         e     exgxa
# 34   0.19  0.76  0.244626  0.99  0.185171  0.264197
# 78   0.53  0.90  0.159177  1.09  0.602986  0.251038
# 33   1.08  2.69  2.524719  3.31 -0.140702  0.211221
# 30   0.79  1.35  0.773836  1.71  0.509041  0.208034
# 135  0.24  1.89  0.421853  2.21  0.076000  0.197850
# 27   0.48  1.49  0.431147  1.58  0.320800  0.177385
# 147  0.32  1.15  0.235769  1.29  0.230127  0.157695
# 72   0.08  0.55  0.080750  0.62  0.036871  0.148161
# 16   0.16  0.88  0.107271  1.13  0.112031  0.148006
# 91   0.35  1.31  0.373327  1.40  0.173154  0.143887
#
#
#               Player  Nation    Pos            Squad  Gls.1  Ast1    GA  xGxA  \
# 148     Luuk de Jong  nl NED     FW          Sevilla   0.26  0.04  0.31  0.45
# 170        Enes Ünal  tr TUR     FW       Valladolid   0.23  0.08  0.31  0.45
# 164   Sandro Ramírez  es ESP  FW,MF       Valladolid   0.21  0.07  0.28  0.43
# 120     Adrián López  es ESP  FW,MF          Osasuna   0.12  0.00  0.12  0.29
# 21     Álvaro Morata  es ESP     FW  Atlético Madrid   0.51  0.09  0.60  0.72
# 24        João Félix  pt POR  FW,MF  Atlético Madrid   0.31  0.05  0.36  0.51
# 63            Wu Lei  cn CHN  FW,MF         Espanyol   0.21  0.00  0.21  0.38
# 96    Guido Carrillo  ar ARG     FW          Leganés   0.07  0.15  0.22  0.39
# 59        Pedro León  es ESP  MF,FW            Eibar   0.05  0.09  0.14  0.34
# 127  Vinicius Júnior  br BRA  FW,MF      Real Madrid   0.20  0.07  0.26  0.45
#
#        KP   Effrate    cc         e     exgxa
# 148  0.79  0.174667  0.83  0.074318 -0.178807
# 170  0.96  0.169287  1.04  0.077328 -0.178807
# 164  0.83  0.343311  0.90 -0.050051 -0.186268
# 120  1.38  0.165826  1.38 -0.110735 -0.188497
# 21   0.99  0.267636  1.08  0.312295 -0.193080
# 24   0.88  0.390500  0.93  0.003544 -0.196423
# 63   0.68  0.262367  0.68 -0.074757 -0.199921
# 96   0.81  0.130039  0.96  0.009290 -0.201191
# 59   2.04  0.260393  2.13 -0.143652 -0.224844
# 127  1.45  0.626428  1.52 -0.228474 -0.228807

# %%
resreg = ols('exgxa ~ Effrate',data=deep).fit(cov_type='HC3')
print(resreg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  exgxa   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     2.240
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):              0.136
# Time:                        20:18:00   Log-Likelihood:                 180.61
# No. Observations:                 181   AIC:                            -357.2
# Df Residuals:                     179   BIC:                            -350.8
# Df Model:                           1
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0132      0.010     -1.318      0.187      -0.033       0.006
# Effrate        0.0524      0.035      1.497      0.134      -0.016       0.121
# ==============================================================================
# Omnibus:                        2.160   Durbin-Watson:                   0.054
# Prob(Omnibus):                  0.340   Jarque-Bera (JB):                1.787
# Skew:                          -0.151   Prob(JB):                        0.409
# Kurtosis:                       3.382   Cond. No.                         4.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
statistics.variance(resreg.resid)
# Out:
# 0.008002420151207121

# %%
resreg2 = ols('GA ~ xGxA + KP',data=deep).fit(cov_type='HC3')
print(resreg2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     GA   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     209.5
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):           1.69e-47
# Time:                        20:18:00   Log-Likelihood:                 178.74
# No. Observations:                 181   AIC:                            -351.5
# Df Residuals:                     178   BIC:                            -341.9
# Df Model:                           2
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0238      0.015     -1.638      0.101      -0.052       0.005
# xGxA           1.1094      0.065     17.042      0.000       0.982       1.237
# KP             0.0102      0.015      0.694      0.488      -0.019       0.039
# ==============================================================================
# Omnibus:                        1.425   Durbin-Watson:                   0.009
# Prob(Omnibus):                  0.491   Jarque-Bera (JB):                1.093
# Skew:                          -0.024   Prob(JB):                        0.579
# Kurtosis:                       3.377   Cond. No.                         10.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
statistics.variance(resreg2.resid)
# Out:
# 0.008169729074127946

# %%
plt.style.use('ggplot')
a = sm.qqplot(resreg2.resid,fit=True)
plt.title('Simple Q-Q Plot')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
plt.rc('figure',figsize=(7,6))
plt.style.use('ggplot')

probplot = sm.ProbPlot(resreg2.get_influence().resid_studentized_internal,fit=True) #qqplot done based on studentized residuals
fig = probplot.qqplot(line='45',marker='o',color='black')
plt.title('Normal Q-Q',fontsize=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
# C:\Users\aleex\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.2980392156862745, 0.4470588235294118, 0.6901960784313725, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
plt.style.use('ggplot')
a = sm.qqplot(xgxa.resid,fit=True)
plt.title('Simple Q-Q Plot')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
plt.rc('figure',figsize=(7,6))
plt.style.use('ggplot')

probplot = sm.ProbPlot(xgxa.get_influence().resid_studentized_internal,fit=True) #qqplot done based on studentized residuals
fig = probplot.qqplot(line='45',marker='o',color='black')
plt.title('Normal Q-Q',fontsize=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
# C:\Users\aleex\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.2980392156862745, 0.4470588235294118, 0.6901960784313725, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
reg2 = ols('e ~ cc', data = deep).fit(cov_type='HC3')
print(reg2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      e   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.7308
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):              0.394
# Time:                        20:18:00   Log-Likelihood:                 80.581
# No. Observations:                 181   AIC:                            -157.2
# Df Residuals:                     179   BIC:                            -150.8
# Df Model:                           1
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0197      0.023     -0.861      0.389      -0.065       0.025
# cc             0.0180      0.021      0.855      0.393      -0.023       0.059
# ==============================================================================
# Omnibus:                       17.939   Durbin-Watson:                   1.754
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.148
# Skew:                           0.697   Prob(JB):                     2.56e-05
# Kurtosis:                       3.929   Cond. No.                         3.91
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
reg3 = ols('e ~ KP', data = deep).fit(cov_type='HC3')
print(reg3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      e   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                   0.05182
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):              0.820
# Time:                        20:18:00   Log-Likelihood:                 80.143
# No. Observations:                 181   AIC:                            -156.3
# Df Residuals:                     179   BIC:                            -149.9
# Df Model:                           1
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0053      0.024     -0.223      0.823      -0.052       0.041
# KP             0.0053      0.023      0.228      0.820      -0.040       0.051
# ==============================================================================
# Omnibus:                       18.622   Durbin-Watson:                   1.749
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.672
# Skew:                           0.733   Prob(JB):                     1.97e-05
# Kurtosis:                       3.850   Cond. No.                         3.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
reg4 = ols('e ~ xGxA', data = deep).fit(cov_type='HC3')
print(reg4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      e   R-squared:                       0.358
# Model:                            OLS   Adj. R-squared:                  0.354
# Method:                 Least Squares   F-statistic:                     21.71
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):           6.16e-06
# Time:                        20:18:00   Log-Likelihood:                 120.22
# No. Observations:                 181   AIC:                            -236.4
# Df Residuals:                     179   BIC:                            -230.0
# Df Model:                           1
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1427      0.026     -5.476      0.000      -0.194      -0.092
# xGxA           0.5405      0.116      4.660      0.000       0.313       0.768
# ==============================================================================
# Omnibus:                       39.552   Durbin-Watson:                   1.560
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.345
# Skew:                          -0.774   Prob(JB):                     1.01e-32
# Kurtosis:                       7.141   Cond. No.                         6.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
regg = ols('GA ~ KP',data=deep).fit(cov_type='HC3')
print(regg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     GA   R-squared:                       0.250
# Model:                            OLS   Adj. R-squared:                  0.246
# Method:                 Least Squares   F-statistic:                     32.43
# Date:                Sat, 11 Feb 2023   Prob (F-statistic):           4.99e-08
# Time:                        20:18:00   Log-Likelihood:                 48.353
# No. Observations:                 181   AIC:                            -92.71
# Df Residuals:                     179   BIC:                            -86.31
# Df Model:                           1
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0886      0.031      2.888      0.004       0.028       0.149
# KP             0.1918      0.034      5.695      0.000       0.126       0.258
# ==============================================================================
# Omnibus:                       43.366   Durbin-Watson:                   1.410
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.573
# Skew:                           1.175   Prob(JB):                     8.67e-18
# Kurtosis:                       5.213   Cond. No.                         3.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
statistics.variance(regg.resid)
# Out:
# 0.03450575758595577
